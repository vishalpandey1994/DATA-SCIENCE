# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe=pd.read_csv('911.csv')

# %%
dataframe.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e
# ...

# %%
dataframe['zip'].value_counts().head(5)
# Out:
# 19401.0    19821
# 19464.0    19276
# 19403.0    14524
# 19446.0    13939
# 19406.0     9601
# Name: zip, dtype: int64

# %%
dataframe['twp'].value_counts().head(5)
# Out:
# LOWER MERION    24826
# ABINGTON        17820
# NORRISTOWN      16546
# UPPER MERION    15288
# CHELTENHAM      13359
# Name: twp, dtype: int64

# %%
dataframe['title'].nunique()
# Out:
# 131

# %%
dataframe['code']=dataframe['title'].apply(lambda title: title.split(':')[0])

# %%
dataframe.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e  code
# ...

# %%
dataframe['code'].value_counts()
# Out:
# EMS        144362
# Traffic    101889
# Fire        42989
# Name: code, dtype: int64

# %%
dataframe['code2']=dataframe['title'].apply(lambda title: title.split(':')[1])

# %%
dt=pd.DataFrame(dataframe['code2'].value_counts().head(10))

# %%
dt
# Out:
#                         code2
#  VEHICLE ACCIDENT -     68123
#  DISABLED VEHICLE -     20667
#  VEHICLE ACCIDENT       16747
#  FIRE ALARM             16359
#  RESPIRATORY EMERGENCY  14637
#  FALL VICTIM            14584
#  CARDIAC EMERGENCY      14491
#  ROAD OBSTRUCTION -      8767
#  SUBJECT IN PAIN         8151
#  HEAD INJURY             7613

# %%
f=plt.plot(dt)

# %%
f

# %%
dataframe['code'].value_counts()
# Out:
# EMS        144362
# Traffic    101889
# Fire        42989
# Name: code, dtype: int64

# %%
sns.countplot(x='code', data=dataframe)

# %%
dt.index.names=['causes']

# %%
dt
# Out:
#                         code2
# causes
#  VEHICLE ACCIDENT -     68123
#  DISABLED VEHICLE -     20667
#  VEHICLE ACCIDENT       16747
#  FIRE ALARM             16359
#  RESPIRATORY EMERGENCY  14637
#  FALL VICTIM            14584
#  CARDIAC EMERGENCY      14491
#  ROAD OBSTRUCTION -      8767
#  SUBJECT IN PAIN         8151
#  HEAD INJURY             7613

# %%
dataframe.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
# ...

# %%
#dataframe['time']=dataframe['timeStamp'].apply(lambda time: time.hour)

# %%
#dataframe['time']=dataframe['title'].apply(lambda my: title.split(':')[0])

# %%
dataframe.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
# ...

# %%
def tittle(coloumn):
    coloumn.split[:](0)

# %%
for i in range(289240):
    ff=dataframe

# %%
dataframe.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
# ...

# %%
def date(column):
    f=pd.to_datetime(column)
    return f

# %%
dataframe['time']=dataframe['timeStamp'].map(pd.to_datetime)

# %%
dataframe.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
# ...

# %%
dataframe['vishall']=dataframe['timeStamp'].apply(date)

# %%
dataframe.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
# ...

# %%
def day(column):
    co=column.day
    return co

# %%
dataframe.tail()
# Out:
#               lat        lng  \
# 289235  40.024967 -75.282905
# 289236  40.024967 -75.282905
# 289237  40.107918 -75.163347
# 289238  40.061922 -75.117655
# 289239  40.098662 -75.352777
#
#                                                      desc      zip  \
# 289235  SCHUYLKILL EXPY & RAMP CITY AVE EB TO I76 WB; ...      NaN
# 289236  SCHUYLKILL EXPY & RAMP CITY AVE EB TO I76 WB; ...      NaN
# 289237  EDGE HILL RD & LIMEKILN PIKE; ABINGTON; 2017-1...  19038.0
# 289238  COVENTRY AVE & NEW SECOND ST; CHELTENHAM; 2017...  19027.0
# 289239  DEKALB PIKE & W BORO LINE RD; UPPER MERION; 20...  19406.0
#
#                               title            timeStamp           twp  \
# 289235        EMS: VEHICLE ACCIDENT  2017-12-30 11:11:36  LOWER MERION
# 289236       Fire: VEHICLE ACCIDENT  2017-12-30 11:11:30  LOWER MERION
# 289237  Traffic: VEHICLE ACCIDENT -  2017-12-30 11:15:24      ABINGTON
# 289238  Traffic: DISABLED VEHICLE -  2017-12-30 11:12:03    CHELTENHAM
# ...

# %%
dataframe['day']=dataframe['time'].map(day)

# %%
dataframe.tail()
# Out:
#               lat        lng  \
# 289235  40.024967 -75.282905
# 289236  40.024967 -75.282905
# 289237  40.107918 -75.163347
# 289238  40.061922 -75.117655
# 289239  40.098662 -75.352777
#
#                                                      desc      zip  \
# 289235  SCHUYLKILL EXPY & RAMP CITY AVE EB TO I76 WB; ...      NaN
# 289236  SCHUYLKILL EXPY & RAMP CITY AVE EB TO I76 WB; ...      NaN
# 289237  EDGE HILL RD & LIMEKILN PIKE; ABINGTON; 2017-1...  19038.0
# 289238  COVENTRY AVE & NEW SECOND ST; CHELTENHAM; 2017...  19027.0
# 289239  DEKALB PIKE & W BORO LINE RD; UPPER MERION; 20...  19406.0
#
#                               title            timeStamp           twp  \
# 289235        EMS: VEHICLE ACCIDENT  2017-12-30 11:11:36  LOWER MERION
# 289236       Fire: VEHICLE ACCIDENT  2017-12-30 11:11:30  LOWER MERION
# 289237  Traffic: VEHICLE ACCIDENT -  2017-12-30 11:15:24      ABINGTON
# 289238  Traffic: DISABLED VEHICLE -  2017-12-30 11:12:03    CHELTENHAM
# ...

# %%
def breakk(column):
    hh=column.split(':')[0]
    return hh

# %%
dataframe['cause']=dataframe['title'].apply(breakk)

# %%
dataframe.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title            timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY  2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY  2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK  2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY  2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS  2015-12-10 16:56:52   LOWER POTTSGROVE
#
# ...

# %%
pd.value_counts(dataframe['cause'])
# Out:
# EMS        144362
# Traffic    101889
# Fire        42989
# Name: cause, dtype: int64

# %%
dataframe['timeStamp']=pd.to_datetime(dataframe['timeStamp'])

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289240 entries, 0 to 289239
# Data columns (total 16 columns):
# lat          289240 non-null float64
# lng          289240 non-null float64
# desc         289240 non-null object
# zip          253942 non-null float64
# title        289240 non-null object
# timeStamp    289240 non-null datetime64[ns]
# twp          289137 non-null object
# addr         289240 non-null object
# e            289240 non-null int64
# code         289240 non-null object
# code2        289240 non-null object
# time         289240 non-null datetime64[ns]
# vishall      289240 non-null datetime64[ns]
# day          289240 non-null int64
# cause        289240 non-null object
# timestamp    289240 non-null datetime64[ns]
# dtypes: datetime64[ns](4), float64(3), int64(2), object(7)
# memory usage: 35.3+ MB

# %%
dataframe['month']=dataframe['timeStamp'].apply(lambda time: time.month)

# %%
#pd.value_counts(dataframe['day'])

# %%
dataframe.head()
# Out:
#          lat        lng                                               desc  \
# 0  40.297876 -75.581294  REINDEER CT & DEAD END;  NEW HANOVER; Station ...
# 1  40.258061 -75.264680  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...
# 2  40.121182 -75.351975  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...
# 3  40.116153 -75.343513  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...
# 4  40.251492 -75.603350  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...
#
#        zip                    title           timeStamp                twp  \
# 0  19525.0   EMS: BACK PAINS/INJURY 2015-12-10 17:10:52        NEW HANOVER
# 1  19446.0  EMS: DIABETIC EMERGENCY 2015-12-10 17:29:21  HATFIELD TOWNSHIP
# 2  19401.0      Fire: GAS-ODOR/LEAK 2015-12-10 14:39:21         NORRISTOWN
# 3  19401.0   EMS: CARDIAC EMERGENCY 2015-12-10 16:47:36         NORRISTOWN
# 4      NaN           EMS: DIZZINESS 2015-12-10 16:56:52   LOWER POTTSGROVE
#
#                          addr  e  code                code2  \
# ...

# %%
gfh=dataframe.groupby(dataframe['month']).count()

# %%
gfh.head()
# Out:
#          lat    lng   desc    zip  title  timeStamp    twp   addr      e  \
# month
# 1      24701  24701  24701  21877  24701      24701  24692  24701  24701
# 2      21663  21663  21663  19161  21663      21663  21658  21663  21663
# 3      22743  22743  22743  20160  22743      22743  22732  22743  22743
# 4      22343  22343  22343  19671  22343      22343  22336  22343  22343
# 5      23093  23093  23093  20254  23093      23093  23082  23093  23093
#
#         code  code2   time  vishall    day  cause  timestamp
# month
# 1      24701  24701  24701    24701  24701  24701      24701
# 2      21663  21663  21663    21663  21663  21663      21663
# 3      22743  22743  22743    22743  22743  22743      22743
# 4      22343  22343  22343    22343  22343  22343      22343
# 5      23093  23093  23093    23093  23093  23093      23093
